# %%
$PSVersionTable
# Out:
# Name                           Value
# ----                           -----
# PSVersion                      7.0.0
# PSEdition                      Core
# GitCommitId                    7.0.0
# OS                             Microsoft Windows 10.0.18363
# Platform                       Win32NT
# PSCompatibleVersions           {1.0, 2.0, 3.0, 4.0…}
# PSRemotingProtocolVersion      2.3
# SerializationVersion           1.1.0.1
# WSManStackVersion              3.0

# %%
$csvFile='D:\PandasInAction\pandas-in-action-master\Chapter 2\movies.csv'

Read-Csv $csvFile | ctmt
# Out:
# <table>
# <thead>
# <tr>
# <th>Rank</th>
# <th>Title</th>
# <th>Studio</th>
# <th>Gross</th>
# <th>Year</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>1</td>
# <td>Avengers: Endgame</td>
# <td>Buena Vista</td>
# <td>$2,796.30</td>
# <td>2019</td>
# </tr>
# <tr>
# <td>2</td>
# <td>Avatar</td>
# <td>Fox</td>
# <td>$2,789.70</td>
# <td>2009</td>
# </tr>
# <tr>
# <td>3</td>
# <td>Titanic</td>
# <td>Paramount</td>
# <td>$2,187.50</td>
# <td>1997</td>
# </tr>
# <tr>
# <td>4</td>
# <td>Star Wars: The Force Awakens</td>
# <td>Buena Vista</td>
# <td>$2,068.20</td>
# <td>2015</td>
# </tr>
# <tr>
# <td>5</td>
# <td>Avengers: Infinity War</td>
# <td>Buena Vista</td>
# <td>$2,048.40</td>
# <td>2018</td>
# </tr>
# <tr>
# <td>6</td>
# <td>Jurassic World</td>
# <td>Universal</td>
# <td>$1,671.70</td>
# <td>2015</td>
# </tr>
# <tr>
# <td>7</td>
# <td>Marvel's The Avengers</td>
# <td>Buena Vista</td>
# <td>$1,518.80</td>
# <td>2012</td>
# </tr>
# <tr>
# <td>8</td>
# <td>Furious 7</td>
# ...

# %%
ps | select Company,Name,Handles -First 5 | ctmt
# Out:
# <table>
# <thead>
# <tr>
# <th>Company</th>
# <th>Name</th>
# <th>Handles</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Microsoft Corporation</td>
# <td>ApplicationFrameHost</td>
# <td>742</td>
# </tr>
# <tr>
# <td>Adobe Systems</td>
# <td>armsvc</td>
# <td>147</td>
# </tr>
# <tr>
# <td>Microsoft Corporation</td>
# <td>audiodg</td>
# <td>572</td>
# </tr>
# <tr>
# <td>Dell Technologies</td>
# <td>AWCC</td>
# <td>881</td>
# </tr>
# <tr>
# <td>Dell Technologies</td>
# <td>AWCC.Background.Server</td>
# <td>1261</td>
# </tr>
# </tbody>
# </table>

# %%
(ps | select Company,Name,Handles,PM,*mem* -first 10).stats() | ctmt
# Out:
# <table>
# <thead>
# <tr>
# <th>ColumnName</th>
# <th>DataType</th>
# <th>HasNulls</th>
# <th>Min</th>
# <th>Max</th>
# <th>Range</th>
# <th>Median</th>
# <th>StandardDeviation</th>
# <th>Variance</th>
# <th>Sum</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Company</td>
# <td>string</td>
# <td>False</td>
# <td></td>
# <td></td>
# <td>0</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr>
# <td>Name</td>
# <td>string</td>
# <td>False</td>
# <td></td>
# <td></td>
# <td>0</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr>
# <td>Handles</td>
# <td>int</td>
# <td>False</td>
# <td>137</td>
# <td>1347</td>
# <td>1210</td>
# <td>458</td>
# <td>407.912082030757</td>
# <td>166392.266666667</td>
# <td>5694</td>
# </tr>
# <tr>
# <td>PM</td>
# <td>int</td>
# <td>False</td>
# <td>1396736</td>
# <td>73388032</td>
# <td>71991296</td>
# <td>18941952</td>
# <td>27299187.7425323</td>
# <td>745245651402024</td>
# <td>285413376</td>
# </tr>
# <tr>
# ...

# %%
(ps | select Company,Name,Handles,PM -first 10).plot('Company','pm')
# Out:
# <div id="a10c7c67-199e-4f2f-9b71-edd43d9d9955" style="width: 900px; height: 500px;"></div>
# <script type="text/javascript">
#
# var renderPlotly = function() {
#     var xplotRequire = requirejs.config({context:'xplot-3.0.1',paths:{plotly:'https://cdn.plot.ly/plotly-1.49.2.min'}});
#     xplotRequire(['plotly'], function(Plotly) {
#
# ...
