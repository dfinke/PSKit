# %% [markdown]
# # Test

# %%
$heating =read-csv https://raw.github.com/vincentarelbundock/Rdatasets/master/csv/Ecdat/Heating.csv
# Out:
# WARNING: One or more headers were not specified. Default names starting with "H" have been used in place of any missing headers.

# %%
$heating.Head() | ctmt
# Out:
# <table>
# <thead>
# <tr>
# <th>H1</th>
# <th>idcase</th>
# <th>depvar</th>
# <th>ic.gc</th>
# <th>ic.gr</th>
# <th>ic.ec</th>
# <th>ic.er</th>
# <th>ic.hp</th>
# <th>oc.gc</th>
# <th>oc.gr</th>
# <th>oc.ec</th>
# <th>oc.er</th>
# <th>oc.hp</th>
# <th>income</th>
# <th>agehed</th>
# <th>rooms</th>
# <th>region</th>
# <th>pb.gc</th>
# <th>pb.gr</th>
# <th>pb.ec</th>
# <th>pb.er</th>
# <th>pb.hp</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>1</td>
# <td>1</td>
# <td>gc</td>
# <td>866</td>
# <td>962.64</td>
# <td>859.9</td>
# <td>995.76</td>
# <td>1135.5</td>
# <td>199.69</td>
# <td>151.72</td>
# <td>553.34</td>
# <td>505.6</td>
# <td>237.88</td>
# <td>7</td>
# <td>25</td>
# <td>6</td>
# <td>ncostl</td>
# <td>4.33672191897441</td>
# <td>6.34484576852096</td>
# <td>1.55401742147685</td>
# <td>1.96946202531646</td>
# <td>4.77341516731125</td>
# </tr>
# <tr>
# <td>2</td>
# <td>2</td>
# <td>gc</td>
# <td>727.93</td>
# <td>758.89</td>
# <td>796.82</td>
# <td>894.69</td>
# <td>968.9</td>
# ...

# %%
$heating.Tail() | ctmt
# Out:
# <table>
# <thead>
# <tr>
# <th>H1</th>
# <th>idcase</th>
# <th>depvar</th>
# <th>ic.gc</th>
# <th>ic.gr</th>
# <th>ic.ec</th>
# <th>ic.er</th>
# <th>ic.hp</th>
# <th>oc.gc</th>
# <th>oc.gr</th>
# <th>oc.ec</th>
# <th>oc.er</th>
# <th>oc.hp</th>
# <th>income</th>
# <th>agehed</th>
# <th>rooms</th>
# <th>region</th>
# <th>pb.gc</th>
# <th>pb.gr</th>
# <th>pb.ec</th>
# <th>pb.er</th>
# <th>pb.hp</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>896</td>
# <td>896</td>
# <td>gc</td>
# <td>766.39</td>
# <td>877.71</td>
# <td>751.59</td>
# <td>869.78</td>
# <td>942.7</td>
# <td>142.61</td>
# <td>136.21</td>
# <td>474.48</td>
# <td>420.65</td>
# <td>203</td>
# <td>6</td>
# <td>20</td>
# <td>4</td>
# <td>mountn</td>
# <td>5.37402706682561</td>
# <td>6.44380001468321</td>
# <td>1.58402883156297</td>
# <td>2.06770474266017</td>
# <td>4.64384236453202</td>
# </tr>
# <tr>
# <td>897</td>
# <td>897</td>
# <td>gc</td>
# <td>1128.5</td>
# <td>1167.8</td>
# <td>1047.6</td>
# <td>1292.6</td>
# ...

# %%
$data = read-json 'http://www.carqueryapi.com/api/0.3/?callback=?&cmd=getModels&make=ford'

# %%
$models = read-json $data.substring(2, ($data.length-4))

# %%
$models.Models
# Out:
# model_name          model_make_id
# ----------          -------------
# 021 C               ford
# 12 M                ford
# 17                  ford
# 17M                 ford
# 2000                ford
# 24.7                ford
# 427                 ford
# 49                  ford
# Aerostar            ford
# Anglia              ford
# Artic               ford
# Aspire              ford
# Bantam              ford
# Bronco              ford
# Bronco II           ford
# C 100               ford
# C-MAX               ford
# C-Max Energi        Ford
# C-Max Hybrid        Ford
# Capri               ford
# Coin                ford
# Consul              ford
# Contour             ford
# Corsair             ford
# Cortina             ford
# Cougar              ford
# Courier             ford
# Crestline           ford
# Crown Victoria      ford
# Custom              ford
# Desert Excursion    ford
# E-150               ford
# E-250               ford
# E-350               ford
# ...
